# %% [markdown]
# ## Import delle librerie

# %%
import ast
import nltk
import pickle
import json

import pandas as pd
import matplotlib.pyplot as plt

import gensim
from gensim import corpora
from gensim import models

import pyLDAvis
import pyLDAvis.gensim_models as gensimvis
pyLDAvis.enable_notebook()

from collections import Counter

# %% [markdown]
# ## Lemmatizzazione

# %%
nltk.download('wordnet')
from nltk.stem.wordnet import WordNetLemmatizer

def get_lemma(token):
    return WordNetLemmatizer().lemmatize(token)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ## Eliminazione delle stopword

# %%
nltk.download('stopwords')
en_stop = set(nltk.corpus.stopwords.words('english'))

def is_stopwords(token):
    if token in en_stop:
        return True
    return False
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Tokenizzazione

# %%
nltk.download('punkt')

def tokenize(text):
    tokens = nltk.word_tokenize(text)
    return tokens
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Lettura e trasformazione dei dati

# %%
def transform(text):
    tokens = tokenize(text)
    tokens = [token.lower() for token in tokens]
    tokens = [token for token in tokens if len(token) > 4]
    tokens = [token for token in tokens if token not in en_stop]
    tokens = [get_lemma(token) for token in tokens]
    return tokens

# %%
data = pd.read_csv("../data/train_data.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12549 entries, 0 to 12548
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         12549 non-null  int64
#  1   category           12549 non-null  object
#  2   headline           12549 non-null  object
#  3   authors            9792 non-null   object
#  4   link               12549 non-null  object
#  5   short_description  10752 non-null  object
#  6   date               12549 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 686.4+ KB

# %%
text_list = data["headline"].tolist()

cleaned_summary_list = [transform(element) for element in text_list]

# %%
print(cleaned_summary_list[0])
# Out:
# ['shooting', 'texas']

# %% [markdown]
# ## Vettorizzazione del corpus

# %%
dictionary = corpora.Dictionary(cleaned_summary_list)

corpus = [dictionary.doc2bow(text) for text in cleaned_summary_list]
tfidf = models.TfidfModel(corpus)  # step 1 -- initialize a model
corpus_tfidf = tfidf[corpus]

pickle.dump(corpus, open('../models/corpus_tfidf.pkl', 'wb'))
dictionary.save('../models/dictionary.gensim')

# %% [markdown]
# ## Addestramento del modello

# %%
num_topics = 5

ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics=num_topics, id2word = dictionary, passes=30, iterations=100,
                   chunksize = 10000, eval_every = 10, random_state=20)

ldamodel.save('../models/model5.gensim')

# %%
topics = ldamodel.print_topics(num_words=10)
for topic in topics:
    print(topic)
# Out:
# (0, '0.016*"shooting" + 0.012*"police" + 0.009*"killed" + 0.006*"prison" + 0.006*"photo" + 0.005*"suspect" + 0.005*"school" + 0.005*"arrested" + 0.005*"killing" + 0.005*"olympics"')
# (1, '0.023*"apple" + 0.013*"space" + 0.012*"iphone" + 0.011*"photo" + 0.009*"video" + 0.008*"planet" + 0.007*"rumor" + 0.007*"science" + 0.006*"first" + 0.006*"earth"')
# (2, '0.009*"found" + 0.007*"allegedly" + 0.007*"police" + 0.007*"woman" + 0.006*"study" + 0.006*"video" + 0.005*"player" + 0.004*"arrested" + 0.004*"football" + 0.004*"google"')
# (3, '0.010*"facebook" + 0.010*"state" + 0.008*"video" + 0.006*"people" + 0.006*"world" + 0.006*"google" + 0.006*"final" + 0.005*"tournament" + 0.005*"player" + 0.004*"score"')
# (4, '0.053*"video" + 0.015*"watch" + 0.010*"youtube" + 0.007*"show" + 0.005*"photo" + 0.005*"tiger" + 0.005*"world" + 0.005*"touchdown" + 0.004*"study" + 0.004*"lebron"')

# %% [markdown]
# ## Test su nuovi dati

# %%
new_headline = 'Two person murdered in New York'

new_headline = transform(new_headline)

new_headline_bow = dictionary.doc2bow(new_headline)

result = ldamodel.get_document_topics(new_headline_bow)

result
# Out:
# [(0, 0.39967823),
#  (1, 0.06758),
#  (2, 0.39855242),
#  (3, 0.066705465),
#  (4, 0.06748388)]

# %%
ldamodel.print_topic(0, topn=10)
# Out:
# '0.016*"shooting" + 0.012*"police" + 0.009*"killed" + 0.006*"prison" + 0.006*"photo" + 0.005*"suspect" + 0.005*"school" + 0.005*"arrested" + 0.005*"killing" + 0.005*"olympics"'

# %% [markdown]
# ## Aggiornamento del modello

# %%
temp_file = "../models/model5.gensim"

# Load a potentially pretrained model from disk.
lda = models.LdaModel.load(temp_file)

new_data = pd.read_csv("../data/new_data.csv")
new_text_list = new_data["headline"].tolist()

new_cleaned_summary_list = [transform(element) for element in text_list]

dictionary = corpora.Dictionary(new_cleaned_summary_list)
new_corpus = [dictionary.doc2bow(text) for text in cleaned_summary_list]

corpus_tfidf = tfidf[new_corpus]

lda.update(corpus_tfidf)

# %%
topics = lda.print_topics(num_words=5)
for topic in topics:
    print(topic)
# Out:
# (0, '0.010*"shooting" + 0.006*"police" + 0.006*"killed" + 0.005*"prison" + 0.004*"suspect"')
# (1, '0.016*"apple" + 0.009*"iphone" + 0.008*"space" + 0.006*"photo" + 0.006*"rumor"')
# (2, '0.005*"found" + 0.004*"allegedly" + 0.004*"police" + 0.004*"study" + 0.004*"woman"')
# (3, '0.007*"facebook" + 0.006*"state" + 0.004*"people" + 0.004*"google" + 0.004*"world"')
# (4, '0.025*"video" + 0.015*"youtube" + 0.013*"watch" + 0.004*"tiger" + 0.004*"show"')

# %% [markdown]
# ## Visualizzazione con pyLDAvis

# %%
lda_display = gensimvis.prepare(lda, corpus_tfidf, dictionary, sort_topics=False)
pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el118140409576538424117130101"></div>
# <script type="text/javascript">
#
# var ldavis_el118140409576538424117130101_data = {"mdsDat": {"x": [-0.20553128080124775, 0.02197353196857353, -0.062107966171816464, 0.11283453292557365, 0.1328311820789171], "y": [0.0572868328221251, -0.23095390299116145, 0.030580661880163357, 0.012898408291964402, 0.13018799999690842], "topics": [1, 2, 3, 4, 5], "cluster": [1, 1, 1, 1, 1], "Freq": [19.935693843585838, 18.08372294075874, 22.33305571055425, 19.75461358532434, 19.892913919776824]}, "tinfo": {"Term": ["video", "apple", "youtube", "watch", "shooting", "iphone", "space", "rumor", "planet", "state", "facebook", "killed", "prison", "found", "police", "tiger", "final", "tournament", "people", "lebron", "photo", "amazon", "science", "google", "score", "killing", "touchdown", "third", "inside", "rover", "shooting", "prison", "sexual", "computer", "assault", "sentenced", "mystery", "startup", "kill", "winter", "convicted", "gunman", "newtown", "party", "sheriff", "solved", "strike", "deputy", "official", "member", "fool", "display", "church", "know", "nassar", "shootout", "drug", "orleans", "wounded", "opening", "scene", "killed", "killing", "olympics", "student", "review", "dinosaur", "police", "school", "mother", "officer", "suspect", "arrested", "alleged", "accused", "report", "year", "photo", "death", "victim", "found", "apple", "iphone", "rumor", "planet", "amazon", "rover", "inside", "march", "samsung", "curiosity", "spacecraft", "manziel", "johnny", "george", "everything", "hacking", "venus", "domestic", "trying", "tsarnaev", "retina", "need", "working", "lunar", "admits", "france", "viking", "account", "becomes", "shuttle", "unlikely", "space", "release", "rocket", "event", "bombing", "station", "science", "earth", "launch", "alien", "photo", "violence", "online", "image", "first", "christmas", "take", "scientist", "video", "year", "google", "facebook", "twitter", "trump", "basketball", "north", "toddler", "carolina", "curry", "telescope", "eclipse", "taking", "drunk", "coming", "protest", "anthem", "minnesota", "shadow", "reality", "couple", "thanksgiving", "smartphones", "volcano", "chess", "likely", "relationship", "marketing", "decision", "skull", "indicted", "stabbing", "pregnant", "aria", "driver", "window", "medium", "shoot", "found", "solar", "allegedly", "mobile", "south", "california", "social", "second", "really", "national", "search", "father", "study", "missing", "woman", "police", "child", "player", "arrested", "suggests", "football", "watch", "google", "show", "video", "world", "texas", "tournament", "final", "third", "baseball", "billion", "league", "huffpost", "trick", "content", "williams", "government", "universe", "brief", "ready", "great", "predict", "penalty", "suspended", "chance", "ronaldo", "radiation", "smartphone", "griffin", "defeat", "come", "higgs", "serena", "sandusky", "raise", "prize", "people", "privacy", "state", "facebook", "arsenal", "score", "michigan", "round", "return", "make", "reason", "google", "story", "world", "soccer", "future", "michael", "player", "video", "football", "first", "could", "youtube", "tiger", "lebron", "playoff", "change", "brother", "alabama", "armstrong", "amazing", "rising", "manning", "field", "notre", "chris", "vine", "peyton", "monday", "raven", "patriot", "united", "eagle", "incredible", "bryant", "changed", "magic", "manhunt", "miller", "manchester", "adorable", "shark", "wood", "video", "watch", "climate", "break", "green", "touchdown", "catch", "thing", "johnson", "show", "sport", "update", "james", "world", "photo", "study", "championship", "player", "police"], "Freq": [197.0, 77.0, 81.0, 99.0, 54.0, 47.0, 49.0, 31.0, 30.0, 44.0, 56.0, 38.0, 25.0, 43.0, 66.0, 23.0, 21.0, 21.0, 29.0, 19.0, 75.0, 17.0, 47.0, 51.0, 27.0, 26.0, 27.0, 16.0, 15.0, 15.0, 53.882636555749215, 25.271722358687494, 14.262850062774739, 12.698291253847415, 12.591216081407955, 11.919857890622811, 11.254884346200521, 11.207491068822456, 10.627729673212242, 10.525677875415628, 9.360298539478901, 9.271287776031949, 8.567809597 ...
